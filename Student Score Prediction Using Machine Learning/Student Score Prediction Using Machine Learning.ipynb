# %%
import pandas as pd
score = pd.read_csv("score.csv")

# %%
score
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
import seaborn as sns
sns.scatterplot(x="Hours", y="Scores", data=score)
# Out:
# <Axes: xlabel='Hours', ylabel='Scores'>

# %%
x = score[["Hours"]].values
y = score["Scores"].values

# %%
import sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
score = LinearRegression()

# %%
score = LinearRegression().fit(x,y)

# %%
score.predict(x).round(2)
# Out:
# array([26.92, 52.34, 33.77, 85.58, 36.7 , 17.15, 92.42, 56.25, 83.62,
#        28.88, 77.76, 60.16, 46.47, 34.74, 13.24, 89.49, 26.92, 21.06,
#        62.12, 74.82, 28.88, 49.41, 39.63, 69.94, 78.73])

# %%
x
# Out:
# array([[2.5],
#        [5.1],
#        [3.2],
#        [8.5],
#        [3.5],
#        [1.5],
#        [9.2],
#        [5.5],
#        [8.3],
#        [2.7],
#        [7.7],
#        [5.9],
#        [4.5],
#        [3.3],
#        [1.1],
#        [8.9],
#        [2.5],
#        [1.9],
#        [6.1],
#        [7.4],
#        [2.7],
#        [4.8],
#        [3.8],
#        [6.9],
#        [7.8]])

# %%
y
# Out:
# array([21, 47, 27, 75, 30, 20, 88, 60, 81, 25, 85, 62, 41, 42, 17, 95, 30,
#        24, 67, 69, 30, 54, 35, 76, 86], dtype=int64)

# %%
from sklearn.metrics import r2_score

# %%
prediction = score.predict(x).round(2)

# %%
r2_score(y,prediction)
# Out:
# 0.9529563202452197

# %%
sns.lmplot(x="Hours", y="Scores", data=score, line_kws={"color": "purple"}, ci=None)
